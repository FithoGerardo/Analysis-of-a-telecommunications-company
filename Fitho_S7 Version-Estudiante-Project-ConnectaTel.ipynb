# %% [markdown]
# # Análisis ConnectaTel
#
# Como **analista de datos**, tu objetivo es evaluar el **comportamiento de los clientes** de una empresa de telecomunicaciones en Latinoamérica, ConnectaTel.
#
# Trabajaremos con información registrada **hasta el año 2024**, lo cual permitirá analizar el comportamiento del negocio dentro de ese periodo.
#
# Para ello trabajarás con tres datasets:
#
# - **plans.csv** → información de los planes actuales (precio, minutos incluidos, GB incluidos, costo por extra)
# - **users.csv** → información de los clientes (edad, ciudad, fecha de registro, plan, churn)
# - **usage.csv** → detalle del **uso real** de los servicios (llamadas y mensajes)
#
# Deberás **explorar**, **limpiar** y **analizar** estos datos para construir un **perfil estadístico** de los clientes, detectar **comportamientos atípicos** y crear **segmentos de clientes**.
#
# Este análisis te permitirá **identificar patrones de consumo**, **diseñar estrategias de retención** y **sugerir mejoras en los planes** ofrecidos por la empresa.
#
# > 💡 Antes de empezar, recuerda pensar de forma **programática**: ¿qué pasos necesitas? ¿En qué orden? ¿Qué quieres medir y por qué?

# %% [markdown]
# ---
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de los tres datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯 Objetivo:**
# Tener los **3 datasets listos en memoria**, entender su contenido y realizar una revisión preliminar.
#
# **Instrucciones:**
# - Importa las librerías necesarias (por ejemplo `pandas`, `seaborn`, `matplotlib.pyplot`)
# - Carga los archivos CSV usando `pd.read_csv()`:
#   - **`/datasets/plans.csv`**
#   - **`/datasets/users_latam.csv`**
#   - **`/datasets/usage.csv`**
# - Guarda los DataFrames en las variables: `plans`, `users`, `usage`.
# - Muestra las primeras filas de cada DataFrame usando `.head()`.

# %%
# importar librerías
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
import seaborn           as sns

# %%
# cargar archivos
# plans = pd.read_csv('/datasets/plans.csv')
# users = pd.read_csv('/datasets/users_latam.csv')
# usage = pd.read_csv('/datasets/usage.csv')

# %%
# Guardar copias
df_list = {"plns": plns, "usrs": usrs, "usge": usge, "user_profile": user_profile}
for name, df in df_list.items():
    df.to_csv(f'{name}.csv', index=False, encoding='utf-8')

# %%
# cargar archivos
plans = pd.read_csv('https://raw.githubusercontent.com/FithoGerardo/Analysis-of-a-telecommunications-company/refs/heads/main/plans.csv')
users = pd.read_csv('https://raw.githubusercontent.com/FithoGerardo/Analysis-of-a-telecommunications-company/refs/heads/main/users_latam.csv')
usage = pd.read_csv('https://raw.githubusercontent.com/FithoGerardo/Analysis-of-a-telecommunications-company/refs/heads/main/usage.csv')

# %%
# mostrar las primeras 5 filas de plans
plans.head(5)
# Out:
#   plan_name  messages_included  gb_per_month  minutes_included  \
# 0    Basico                100             5               100
# 1   Premium                500            20               600
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute
# 0               12         1.2             0.08            0.10
# 1               25         1.0             0.05            0.07

# %%
# mostrar las primeras 5 filas de users
users.head(5)
# Out:
#    user_id first_name last_name  age      city                       reg_date  \
# 0    10000     Carlos    Garcia   38  Medellín  2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres   53         ?  2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez   57      CDMX  2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez   69    Bogotá  2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres   63       GDL  2022-01-02 02:17:11.657914478
#
#       plan churn_date
# 0   Basico        NaN
# 1   Basico        NaN
# 2   Basico        NaN
# 3  Premium        NaN
# 4   Basico        NaN

# %%
# mostrar las primeras 5 filas de usage
usage.head(5)
# Out:
#    id  user_id  type                           date  duration  length
# 0   1    10332  call  2024-01-01 00:00:00.000000000      0.09     NaN
# 1   2    11458  text  2024-01-01 00:06:30.969774244       NaN    39.0
# 2   3    11777  text  2024-01-01 00:13:01.939548488       NaN    36.0
# 3   4    10682  call  2024-01-01 00:19:32.909322733      1.53     NaN
# 4   5    12742  call  2024-01-01 00:26:03.879096977      4.84     NaN

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# ### 1.2 Exploración de la estructura de los datasets
#
# **🎯 Objetivo:**
# Conocer la **estructura de cada dataset**, revisar cuántas filas y columnas tienen, identificar los **tipos de datos** de cada columna y detectar posibles **inconsistencias o valores nulos** antes de iniciar el análisis.
#
# **Instrucciones:**
# - Revisa el **número de filas y columnas** de cada dataset usando `.shape`.
# - Usa `.info()` en cada DataFrame para obtener un **resumen completo** de columnas, tipos de datos y valores no nulos.

# %%
# revisar el número de filas y columnas de cada dataset
print("plans", plans.shape)
print("users", users.shape)
print("usage", usage.shape)
# Out:
# plans (2, 8)
# users (4000, 8)
# usage (40000, 6)

# %%
# inspección de plans con .info()
plans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   plan_name          2 non-null      object
#  1   messages_included  2 non-null      int64
#  2   gb_per_month       2 non-null      int64
#  3   minutes_included   2 non-null      int64
#  4   usd_monthly_pay    2 non-null      int64
#  5   usd_per_gb         2 non-null      float64
#  6   usd_per_message    2 non-null      float64
#  7   usd_per_minute     2 non-null      float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 260.0+ bytes

# %%
# inspección de users con .info()
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     4000 non-null   int64
#  1   first_name  4000 non-null   object
#  2   last_name   4000 non-null   object
#  3   age         4000 non-null   int64
#  4   city        3531 non-null   object
#  5   reg_date    4000 non-null   object
#  6   plan        4000 non-null   object
#  7   churn_date  466 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 250.1+ KB

# %%
# inspección de usage con .info()
usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        40000 non-null  int64
#  1   user_id   40000 non-null  int64
#  2   type      40000 non-null  object
#  3   date      39950 non-null  object
#  4   duration  17924 non-null  float64
#  5   length    22104 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Creando copias para trabajar con dichas copias

# %%
# copia de plans, users y usage
plns = plans.copy()
usrs = users.copy()
usge = usage.copy()

df_list = {"plns": plns, "usrs": usrs, "usge": usge}
for name, df in df_list.items():
    df.info()
    display(df.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   plan_name          2 non-null      object
#  1   messages_included  2 non-null      int64
#  2   gb_per_month       2 non-null      int64
#  3   minutes_included   2 non-null      int64
#  4   usd_monthly_pay    2 non-null      int64
#  5   usd_per_gb         2 non-null      float64
#  6   usd_per_message    2 non-null      float64
#  7   usd_per_minute     2 non-null      float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 260.0+ bytes
#   plan_name  messages_included  gb_per_month  minutes_included  \
# 0    Basico                100             5               100
# 1   Premium                500            20               600
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute
# 0               12         1.2             0.08            0.10
# ...

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Identificación de problemas de calidad de datos
#
# ### 2.1 Revisión de valores nulos
#
# **🎯 Objetivo:**
# Detectar la presencia y magnitud de valores faltantes para evaluar si afectan el análisis o requieren imputación/eliminación.
#
# **Instrucciones:**
# - Cuenta valores nulos por columna para cada dataset.
# - Calcula la proporción de nulos por columna para cada dataset.
#
# El dataset `plans` solamente tiene 2 renglones y se puede observar que no tiene ausentes, por ello no necesita exploración adicional.
#
# <br>
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa `.isna().sum()` para contar valores nulos y usa `.isna().mean()` para calcular la proporción.

# %%
# cantidad de nulos para users
display(usrs.isna().sum()) # Cantidad de valores nulos
print()
display(usrs.isna().mean()) # Proporción de valores nulos
# Out:
# user_id          0
# first_name       0
# last_name        0
# age              0
# city           469
# reg_date         0
# plan             0
# churn_date    3534
# dtype: int64
# user_id       0.00000
# first_name    0.00000
# last_name     0.00000
# age           0.00000
# city          0.11725
# reg_date      0.00000
# plan          0.00000
# churn_date    0.88350
# dtype: float64

# %%
# cantidad de nulos para usage
display(usge.isna().sum()) # Cantidad de valores nulos
print()
display(usge.isna().mean()) # Proporción de valores nulos
# Out:
# id              0
# user_id         0
# type            0
# date           50
# duration    22076
# length      17896
# dtype: int64
# id          0.00000
# user_id     0.00000
# type        0.00000
# date        0.00125
# duration    0.55190
# length      0.44740
# dtype: float64

# %% [markdown]
#  - Si una columna tiene **más del 80–90% de nulos**, normalmente se **ignora o elimina**.
#  - Si tiene **entre 5% y 30%**, generalmente se **investiga para imputar o dejar como nulos**.
#  - Si es **menor al 5%**, suele ser un caso simple de imputación o dejar como nulos.
#
#  ---
#
# **Valores nulos**
# - ¿Qué columnas tienen valores faltantes y en qué proporción?
# - Indica qué harías: ¿imputar, eliminar, ignorar?

# %% [markdown]
# **Comentarios**:
# * **Porcentaje con base a nulos, no al total de registros.**
# - * Tabla Users:
# * 11.72% de los usuarios no tienen una ciudad registrada. Afectando segmentación geográfica. (Imputar) usrs['city'] = usrs['city'].fillna('Unknown')
# * 88.35% Churn date en NaN, indicando usuarios activos. (Ignorar) Crear flag: usrs['is_churned'] = usrs['churn_date'].notna()
# - * Tabla Usage:
# * 0.125% Date, se puede eliminar por ser porcentaje bajo. (Eliminar) usge = usge.dropna(subset=['date'])
# * 55.19% Call Duration: 45% de usuarios han hecho llamadas. (Ignorar)
# * 44.74% SMS Length: 55% de usuarios han usado mensajes del plan. (Ignorar)

# %% [markdown]
# ### 2.2 Detección de valores inválidos y sentinels
#
# 🎯 **Objetivo:**
# Identificar sentinels: valores que no deberían estar en el dataset.
#
# **Instrucciones:**
# - Explora las columnas numéricas con **un resumen estadístico** y describe brevemente que encontraste.
# - Explora las columnas categóricas **relevantes**, revisando sus valores únicos y describe brevemente que encontraste.
#
#
# El dataset `plans` solamente tiene 2 renglones, por ello no necesita exploración adicional.

# %%
# Ver lista con nombre de columnas users y usage
display(usrs.columns)
print()
display(usge.columns)
# Out:
# Index(['user_id', 'first_name', 'last_name', 'age', 'city', 'reg_date', 'plan',
#        'churn_date'],
#       dtype='object')
# Index(['id', 'user_id', 'type', 'date', 'duration', 'length'], dtype='object')

# %%
# Identificando columnas numéricas, categóricas y de fecha de cada tabla
# Users
usrs_num_cols = ['user_id', 'age']
usrs_cat_cols = ['city', 'plan']
usrs_date_cols = ['reg_date']

# Usage
usge_num_cols = ['id', 'user_id', 'duration', 'length']
usge_cat_cols = ['type']
usge_date_cols = ['date']

# %%
# Función para desplegar describe y value_counts por tabla
# de columnas numéricas, categóricas y fecha

usrs_cols = {
    "numéricas": usrs_num_cols,
    "categóricas": usrs_cat_cols,
    "fecha": usrs_date_cols
}
usge_cols = {
    "numéricas": usge_num_cols,
    "categóricas": usge_cat_cols,
    "fecha": usge_date_cols
}

# Introducir dataframe y su diccionario de columnas
def df_describe_value_counts(df, cols_dict):
    for tipo, cols in cols_dict.items():
        print(f"Columnas {tipo}")

        display(df[cols].describe())
        print()

        display(df[cols].value_counts().reset_index())
        print()

# %%
df_describe_value_counts(usrs, usrs_cols)
# Out:
# Columnas numéricas
#             user_id          age
# count   4000.000000  4000.000000
# mean   11999.500000    33.739750
# std     1154.844867   123.232257
# min    10000.000000  -999.000000
# 25%    10999.750000    32.000000
# 50%    11999.500000    47.000000
# 75%    12999.250000    63.000000
# max    13999.000000    79.000000
#       user_id  age  count
# 0       13983   45      1
# 1       13982   23      1
# 2       13981   74      1
# 3       13980   61      1
# 4       13979   73      1
# ...       ...  ...    ...
# 3995    10004   63      1
# 3996    10003   69      1
# 3997    10002   57      1
# 3998    10001   53      1
# 3999    10000   38      1
#
# [4000 rows x 3 columns]
# Columnas categóricas
#           city    plan
# count     3531    4000
# unique       7       2
# top     Bogotá  Basico
# freq       808    2595
#         city     plan  count
# 0     Bogotá   Basico    522
# 1       CDMX   Basico    474
# 2   Medellín   Basico    398
# ...

# %% [markdown]
# ---
# **Users**

# %% [markdown]
# - La columna `user_id`: Funciona únicamente como identificador, por lo que no será útil para análisis estadísticos.
# - La columna `age`: El valor -999 debe tratarse como dato faltante y convertirse en NaN antes de continuar con el análisis. EJ.: (Imputar)
# `usrs['age'] = usrs['age'].replace(-999, np.nan)`

# %% [markdown]
# - La columna `city`: 7 Ciudades únicas. Top: Bogotá (808 usuarios). 469 faltantes. (Imputar) `usrs['city'] = usrs['city'].fillna('Unknown')`
# - La columna `plan`: Top: Básico (2595 usuarios)

# %%
df_describe_value_counts(usge, usge_cols)
# Out:
# Columnas numéricas
#                 id       user_id      duration        length
# count  40000.00000  40000.000000  17924.000000  22104.000000
# mean   20000.50000  12002.405975      5.202237     52.127398
# std    11547.14972   1157.279564      6.842701     56.611183
# min        1.00000  10000.000000      0.000000      0.000000
# 25%    10000.75000  10996.000000      1.437500     37.000000
# 50%    20000.50000  12013.000000      3.500000     50.000000
# 75%    30000.25000  13005.000000      6.990000     64.000000
# max    40000.00000  13999.000000    120.000000   1490.000000
#        id  user_id  duration  length  count
# 0    1415    10399    120.00    65.0      1
# 1    1825    12936    120.00    40.0      1
# 2    1933    10189    120.00    69.0      1
# 3    2071    13139      1.68  1490.0      1
# 4    2973    10085    120.00    68.0      1
# 5    5273    11750      3.78  1490.0      1
# 6   10615    13855      0.53  1490.0      1
# ...

# %% [markdown]
# ---
# **Usage**

# %% [markdown]
# - Las columnas `id` y `user_id`: `id` identificador único de cada registro de uso. `user_id`: Relaciona cada evento de uso con un usuario. Clave para relacionar actividad con características de usuario.
# - La columna `duration`: Llamadas. Avg: 5.2 min.
# - La columna `length`: Textos. Avg: 52 caracteres por texto. Max: 1490, posible mensaje concatenado, registro atípico, posibles outliers.

# %% [markdown]
# - La columna `type`: Llamadas y textos solamente.
# 17,908 llamadas y 22,092 textos.

# %% [markdown]
# ---
# **Comentarios**:
# - Se detectó un valor inválido (-999) en la variable age que debe tratarse como dato faltante. (imputar Unknown)
# - La mayoría de los usuarios utilizan el plan Básico, lo cual puede influir en el patrón de consumo. (Ignorar).
# - El dataset de uso contiene dos tipos de actividad (llamadas y mensajes), lo que explica los valores faltantes en duration y length. (Ignorar).
# - Se identificaron posibles outliers en la longitud de mensajes (length) que podrían explorarse más adelante. (Posibles mensajes concatenados, registro atípico, posibles outliers).

# %% [markdown]
# ### 2.3 Revisión y estandarización de fechas
#
# **🎯 Objetivo:**
# Asegurar que las columnas de fecha estén correctamente formateadas y detectar años fuera de rango que indiquen errores de captura.
#
# **Instrucciones:**
# - Convierte las columnas de fecha a tipo fecha y asegurate de que el código sea a prueba de errores.
# - Revisa cuántas veces aparece cada año.
# - Identifica fechas imposibles (ej. años futuros o negativos).
#
# Toma en cuenta que tenemos datos registrados hasta el año 2024.

# %%
# Revisando churn_date
usrs['churn_date'].info()
usrs['churn_date'].value_counts().head(3)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4000 entries, 0 to 3999
# Series name: churn_date
# Non-Null Count  Dtype
# --------------  -----
# 466 non-null    object
# dtypes: object(1)
# memory usage: 31.4+ KB
# churn_date
# 1,71763E+18    6
# 1,71841E+18    6
# 1,72238E+18    6
# Name: count, dtype: int64

# %% [markdown]
# `churn_date` está en timestamp Unix en nanosegundos.
#
# Los timestamps de pandas suelen estar en: nanosegundos
# 10^18

# %%
# Remplazar coma por punto
usrs['churn_date'] = usrs['churn_date'].str.replace(',', '.', regex=False)
usrs['churn_date'].info()
usrs['churn_date'].value_counts().head(3)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4000 entries, 0 to 3999
# Series name: churn_date
# Non-Null Count  Dtype
# --------------  -----
# 466 non-null    object
# dtypes: object(1)
# memory usage: 31.4+ KB
# churn_date
# 1.71763E+18    6
# 1.71841E+18    6
# 1.72238E+18    6
# Name: count, dtype: int64

# %%
# Convertir churn_date a numérico
usrs['churn_date'] = pd.to_numeric(usrs['churn_date'], errors='coerce')
usrs['churn_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4000 entries, 0 to 3999
# Series name: churn_date
# Non-Null Count  Dtype
# --------------  -----
# 466 non-null    float64
# dtypes: float64(1)
# memory usage: 31.4 KB

# %%
# Convertir churn_date a fecha
usrs['churn_date'] = pd.to_datetime(usrs['churn_date'], unit='ns')
# Confirmando cambios
usrs['churn_date'].info()
usrs['churn_date'].value_counts().head(3)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4000 entries, 0 to 3999
# Series name: churn_date
# Non-Null Count  Dtype
# --------------  -----
# 466 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 31.4 KB
# churn_date
# 2024-06-05 23:26:40    6
# 2024-06-15 00:06:40    6
# 2024-07-30 22:53:20    6
# Name: count, dtype: int64

# %%
# Función para convertir columnas a fecha
def convertir_a_fecha(df, columnas):
    for col in columnas:
        df[col] = pd.to_datetime(df[col], errors = "coerce")

# %%
# Utilizando función en ambas tablas
convertir_a_fecha(usrs, usrs_date_cols)
convertir_a_fecha(usge, usge_date_cols)

# Checar conversión
print("Users")
usrs.info()
print("\nUsage")
usge.info()
# Out:
# Users
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     4000 non-null   int64
#  1   first_name  4000 non-null   object
#  2   last_name   4000 non-null   object
#  3   age         4000 non-null   int64
#  4   city        3531 non-null   object
#  5   reg_date    4000 non-null   datetime64[ns]
#  6   plan        4000 non-null   object
#  7   churn_date  466 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 250.1+ KB
#
# Usage
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        40000 non-null  int64
#  1   user_id   40000 non-null  int64
#  2   type      40000 non-null  object
#  3   date      39950 non-null  datetime64[ns]
# ...

# %%
# Revisar los años presentes en `reg_date` de users
usrs['reg_date'].dt.year.value_counts().sort_index().reset_index()
# Out:
#    reg_date  count
# 0      2022   1314
# 1      2023   1316
# 2      2024   1330
# 3      2026     40

# %%
(usrs['reg_date'].dt.year > 2024).sum()
# Out:
# np.int64(40)

# %% [markdown]
# En `reg_date`: la mayoría de los registros de registro (reg_date) se concentran entre 2022 y 2024, lo cual es consistente con el periodo esperado de datos.
#
# Sin embargo, se identificaron 40 registros con año 2026, lo cual es un valor fuera del rango esperado, ya que el dataset solo debería contener datos hasta 2024. Esto sugiere errores de captura o digitación.
#
# Los registros con fechas futuras deberán revisarse o marcarse como valores inválidos antes de continuar con el análisis.

# %%
# Revisar los años presentes en `date` de usage
usge['date'].dt.year.value_counts().sort_index().reset_index()
# Out:
#      date  count
# 0  2024.0  39950

# %% [markdown]
# En `date`: Todos los registros de actividad corresponden al año 2024, lo cual es consistente con el periodo de análisis.

# %% [markdown]
# ---
# **Comentarios**: Errores de captura en fechas futuras (2026) que podrían afectar análisis temporales como crecimiento de usuarios o churn.
#
# Se recomienda **cambiar** esas fechas con `usrs.loc[usrs['reg_date'].dt.year > 2024, 'reg_date'] = pd.NaT`

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Limpieza básica de datos
#
# ### 3.1 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Aplicar reglas de limpieza para reemplazar valores sentinels y corregir fechas imposibles.
#
# **Instrucciones:**
# - En `age`, reemplaza el sentinel **-999** con la mediana.
# - En `city`, reemplaza el sentinel `"?"` por valores nulos (`pd.NA`).
# - Marca como nulas (`pd.NA`) las fechas fuera de rango.

# %% [markdown]
# ---
# ### *Check list*
# - Reemplazar -999 por la mediana de age [y]
# - Reemplazar ? por NA en city [y]
# - Convertir los faltantes de numpy en string para que pandas lo reconozca como pd.NA [y]
# - Convertir vacios de city a 'unknown' [y]
# - Marcar fechas futuras como NA para reg_date [y]
# - Eliminar vacíos de `date`  [y]
# - Crear flag de churn_date [y]
# - Dejando vacíos los valores que no pertenecen a call y text respectivamente [y]

# %%
# Crear flag de churn
usrs['is_churned'] = usrs['churn_date'].notna().astype(int)
# Verificando
# 0 = No - 1 = Si
usrs['is_churned'].value_counts(dropna=False)
# Out:
# is_churned
# 0    3534
# 1     466
# Name: count, dtype: int64

# %%
# Reemplazar -999 por la mediana de age
age_mediana = usrs.loc[usrs['age'] != -999, 'age'].median()
usrs['age'] = usrs['age'].replace(-999, age_mediana)

# Verificar cambios
usrs['age'].describe()
# Out:
# count    4000.000000
# mean       48.136000
# std        17.689919
# min        18.000000
# 25%        33.000000
# 50%        48.000000
# 75%        63.000000
# max        79.000000
# Name: age, dtype: float64

# %%
# Ajustar string de 'city'
usrs['city'] = (usrs['city'].str.strip().str.lower()
    .replace({"gdl": "guadalajara", "mty": "monterrey"})
)

# %%
# Reemplazar ? por NA en city
usrs['city'] = usrs['city'].replace('?', pd.NA)
# Convertir los faltantes de numpy en string para que pandas lo reconozca como pd.NA
usrs['city'] = usrs['city'].astype('string')
# Convertir vacios a 'unknown'
usrs['city'] = usrs['city'].fillna('Unknown')


# Verificar cambios
display(usrs['city'].describe())
print()
display(usrs['city'].value_counts(dropna=False).sort_index().reset_index())
print()
display(usrs[usrs['city'].isna()])
# Out:
# count       4000
# unique         7
# top       bogotá
# freq         808
# Name: city, dtype: object
#           city  count
# 0      Unknown    565
# 1       bogotá    808
# 2         cali    424
# 3         cdmx    730
# 4  guadalajara    450
# 5     medellín    616
# 6    monterrey    407
# Empty DataFrame
# Columns: [user_id, first_name, last_name, age, city, reg_date, plan, churn_date, is_churned]
# Index: []

# %%
# Marcar fechas futuras como NA para reg_date
usrs.loc[usrs['reg_date'].dt.year > 2024, 'reg_date'] = pd.NaT

# Verificar cambios
usrs['reg_date'].describe()
# Out:
# count                             3960
# mean     2023-07-03 21:39:41.095273728
# min                2022-01-01 00:00:00
# 25%      2022-10-02 20:17:11.657914368
# 50%      2023-07-04 10:00:05.401350400
# 75%      2024-04-03 04:00:05.401350400
# max                2024-12-31 00:00:00
# Name: reg_date, dtype: object

# %%
# Eliminar registros sin fecha en usage
usge = usge.dropna(subset=['date'])
usge['date'].describe()
# Out:
# count                            39950
# mean     2024-03-31 11:58:45.887006208
# min                2024-01-01 00:00:00
# 25%      2024-02-15 05:56:44.515112960
# 50%      2024-03-31 12:06:30.969774336
# 75%      2024-05-15 18:09:46.454661376
# max                2024-06-30 00:00:00
# Name: date, dtype: object

# %%
# Checando los posibles outliers de los mensajes
display(usge['length'].describe(percentiles=[0.90,0.95,0.99]))
display(usge[usge['length'] > 100])
# Out:
# count    22080.000000
# mean        52.133062
# std         56.639224
# min          0.000000
# 50%         50.000000
# 90%         76.000000
# 95%         83.000000
# 99%         97.000000
# max       1490.000000
# Name: length, dtype: float64
#           id  user_id  type                          date  duration  length
# 43        44    11882  text 2024-01-01 04:40:11.700292507       NaN   104.0
# 205      206    11244  text 2024-01-01 22:15:48.803720093       NaN   103.0
# 231      232    11826  text 2024-01-02 01:05:14.017850446       NaN   104.0
# 634      635    12130  text 2024-01-03 20:51:14.836870921       NaN   101.0
# 637      638    11315  text 2024-01-03 21:10:47.746193654       NaN   104.0
# ...      ...      ...   ...                           ...       ...     ...
# 36796  36797    12576  text 2024-06-15 12:08:43.813095326       NaN   101.0
# 37452  37453    11167  text 2024-06-18 11:23:19.984999624       NaN   105.0
# ...

# %% [markdown]
# ---
# Posible outlier, error de tipado en duration length
#
# ---
# id	type	duration	length
#
# 37982	call	0.93	1490
#
# ---
# Error de registro o mezcla de campos

# %%
# Función para verificar registros erróneos de call y text
def check_reg_call_text():

    call_errors = ((df['type'] == 'call') & (df['length'].notna())).sum()
    text_errors = ((df['type'] == 'text') & (df['duration'].notna())).sum()

    print("Call con length:", call_errors)
    print("Text con duration:", text_errors)
    print("Total inconsistencias:", call_errors + text_errors)
    print()
    display(df[(df['type']=='call') & (df['length'].notna())].shape)
    display(df[(df['type']=='text') & (df['duration'].notna())].shape)

# %%
# Verificando si hay registros erróneos
check_reg_call_text()
# Out:
# Call con length: 12
# Text con duration: 16
# Total inconsistencias: 28
# (12, 6)
# (16, 6)

# %%
# Dejando vacíos los valores que no pertenecen a call y text respectivamente
usge.loc[usge['type'] == 'call', 'length'] = np.nan
usge.loc[usge['type'] == 'text', 'duration'] = np.nan

# %%
# Checando resultados
check_reg_call_text()
# Out:
# Call con length: 12
# Text con duration: 16
# Total inconsistencias: 28
# (12, 6)
# (16, 6)

# %% [markdown]
# ### 3.2 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Decidir qué hacer con los valores nulos según su proporción y relevancia.
#
# **Instrucciones:**
# - Verifica si los nulos en `duration` y `length` son **MAR**(Missing At Random) revisando si dependen de la columna `type`.
#   Si confirmas que son MAR, **déjalos como nulos** y justifica la decisión.

# %%
# Verificación MAR en usage (Missing At Random) para duration
usge['duration'].isna().groupby(usge['type']).mean().sort_values(ascending = False)
# Out:
# type
# text    1.0
# call    0.0
# Name: duration, dtype: float64

# %%
# Verificación MAR en usage (Missing At Random) para length
usge['length'].isna().groupby(usge['type']).mean().sort_values(ascending = False)
# Out:
# type
# call    1.0
# text    0.0
# Name: length, dtype: float64

# %% [markdown]
# Los valores nulos en duration y length dependen completamente del tipo de actividad `type`:
#
# `duration` está presente solo cuando type = call
#
# `length` está presente solo cuando type = text
#
# Esto confirma que los valores faltantes son MAR (Missing At Random), ya que su ausencia está explicada por una variable observada del dataset `type`.

# %% [markdown]
# **Confirmar cambios en `users` y `usage`**

# %%
# Se agregó columna 'churn_date','is_churned'
usrs_date_cols = ['reg_date', 'churn_date', 'is_churned']
usrs_cols = {
    "numéricas": usrs_num_cols,
    "categóricas": usrs_cat_cols,
    "fecha": usrs_date_cols
}

# %%
df_describe_value_counts(usrs, usrs_cols)
# Out:
# Columnas numéricas
#             user_id          age
# count   4000.000000  4000.000000
# mean   11999.500000    48.136000
# std     1154.844867    17.689919
# min    10000.000000    18.000000
# 25%    10999.750000    33.000000
# 50%    11999.500000    48.000000
# 75%    12999.250000    63.000000
# max    13999.000000    79.000000
#       user_id  age  count
# 0       13983   45      1
# 1       13982   23      1
# 2       13981   74      1
# 3       13980   61      1
# 4       13979   73      1
# ...       ...  ...    ...
# 3995    10004   63      1
# 3996    10003   69      1
# 3997    10002   57      1
# 3998    10001   53      1
# 3999    10000   38      1
#
# [4000 rows x 3 columns]
# Columnas categóricas
#           city    plan
# count     4000    4000
# unique       7       2
# top     bogotá  Basico
# freq       808    2595
#            city     plan  count
# 0        bogotá   Basico    522
# 1          cdmx   Basico    474
# 2      medellín   Basico    398
# ...

# %%
df_describe_value_counts(usge, usge_cols)
# Out:
# Columnas numéricas
#                  id       user_id      duration        length
# count  39950.000000  39950.000000  17882.000000  22068.000000
# mean   20000.310438  12002.428761      5.100782     51.351187
# std    11548.148869   1157.421395      5.924534     45.660186
# min        1.000000  10000.000000      0.000000      0.000000
# 25%    10000.250000  10995.250000      1.430000     37.000000
# 50%    20001.500000  12013.000000      3.500000     50.000000
# 75%    30001.750000  13005.000000      6.970000     64.000000
# max    40000.000000  13999.000000    120.000000   1490.000000
# Empty DataFrame
# Columns: [id, user_id, duration, length, count]
# Index: []
# Columnas categóricas
#          type
# count   39950
# unique      2
# top      text
# freq    22068
#    type  count
# 0  text  22068
# 1  call  17882
# Columnas fecha
#                                 date
# count                          39950
# mean   2024-03-31 11:58:45.887006208
# ...

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Summary statistics de uso por usuario
#
#
# ### 4.1 Agrupación por comportamiento de uso
#
# 🎯**Objetivo**: Resumir las variables clave de la tabla `usage` **por usuario**, creando métricas que representen su comportamiento real de uso histórico.
#
# **Instrucciones:**:
# 1. Construye una tabla agregada de `usage` por `user_id` que incluya:
# - número total de mensajes
# - número total de llamadas
# - total de minutos de llamadas
#
# 2. Renombra las columnas para que tengan nombres claros:
# - `cant_mensajes`
# - `cant_llamadas`
# - `cant_minutos_llamada`
# 3. Combina esta tabla con `users`.

# %%
# Columnas auxiliares
usge["is_text"] = (usge["type"] == "text").astype(int) #conocer el total de mensajes
usge["is_call"] = (usge["type"] == "call").astype(int) #conocer el total de llamadas

# Agrupar información por usuario
usage_agg = (
    usge
    .groupby("user_id")
    .agg({
        "is_text": "sum",
        "is_call": "sum",
        "duration": "sum"
    })
    .reset_index()
)
# observar resultado
usage_agg.head(3)
# Out:
# /tmp/ipykernel_14374/1267168086.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usge["is_text"] = (usge["type"] == "text").astype(int) #conocer el total de mensajes
# /tmp/ipykernel_14374/1267168086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usge["is_call"] = (usge["type"] == "call").astype(int) #conocer el total de llamadas
#    user_id  is_text  is_call  duration
# 0    10000        7        3     23.70
# 1    10001        5       10     33.18
# ...

# %%
# Renombrar columnas
usage_agg = usage_agg.rename(columns={
    "is_text": "cant_mensajes",
    "is_call": "cant_llamadas",
    "duration": "cant_minutos_llamada"
})
# observar resultado
usage_agg.head(3)
# Out:
#    user_id  cant_mensajes  cant_llamadas  cant_minutos_llamada
# 0    10000              7              3                 23.70
# 1    10001              5             10                 33.18
# 2    10002              5              2                 10.74

# %%
# Combinar la tabla agregada con el dataset de usuarios
user_profile = usrs.merge(
    usage_agg,
    on="user_id",
    how="left"
)
user_profile.head(5)
# Out:
#    user_id first_name last_name  age         city  \
# 0    10000     Carlos    Garcia   38     medellín
# 1    10001      Mateo    Torres   53      Unknown
# 2    10002      Sofia   Ramirez   57         cdmx
# 3    10003      Mateo   Ramirez   69       bogotá
# 4    10004      Mateo    Torres   63  guadalajara
#
#                        reg_date     plan churn_date  is_churned  \
# 0 2022-01-01 00:00:00.000000000   Basico        NaT           0
# 1 2022-01-01 06:34:17.914478619   Basico        NaT           0
# 2 2022-01-01 13:08:35.828957239   Basico        NaT           0
# 3 2022-01-01 19:42:53.743435858  Premium        NaT           0
# 4 2022-01-02 02:17:11.657914478   Basico        NaT           0
#
#    cant_mensajes  cant_llamadas  cant_minutos_llamada
# 0            7.0            3.0                 23.70
# 1            5.0           10.0                 33.18
# 2            5.0            2.0                 10.74
# 3           11.0            3.0                  8.99
# ...

# %%
user_profile.shape
display(user_profile.info())
display(user_profile.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               4000 non-null   int64
#  1   first_name            4000 non-null   object
#  2   last_name             4000 non-null   object
#  3   age                   4000 non-null   int64
#  4   city                  4000 non-null   string
#  5   reg_date              3960 non-null   datetime64[ns]
#  6   plan                  4000 non-null   object
#  7   churn_date            466 non-null    datetime64[ns]
#  8   is_churned            4000 non-null   int64
#  9   cant_mensajes         3999 non-null   float64
#  10  cant_llamadas         3999 non-null   float64
#  11  cant_minutos_llamada  3999 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(3), string(1)
# memory usage: 375.1+ KB
# None
# ...

# %%
profile_cols = ['cant_mensajes', 'cant_llamadas', 'cant_minutos_llamada']

for col in profile_cols:
  print(f"Filas en 0 de columna: {col}")
  display(user_profile.loc[user_profile[col] == 0].shape)
# Out:
# Filas en 0 de columna: cant_mensajes
# (18, 12)
# Filas en 0 de columna: cant_llamadas
# (42, 12)
# Filas en 0 de columna: cant_minutos_llamada
# (42, 12)

# %% [markdown]
# ### 4.2 4.2 Resumen estadístico por usuario durante el 2024
#
# 🎯 **Objetivo:** Analizar las columnas numéricas y categóricas de los usuarios, para identificar rangos, valores extremos y distribución de los datos antes de continuar con el análisis.
#
# **Instrucciones:**
# 1. Para las columnas **numéricas** relevantes, obtén un resumen estadístico (media, mediana, mínimo, máximo, etc.).
# 2. Para la columna **categórica** `plan`, revisa la distribución en **porcentajes** de cada categoría.

# %%
# Resumen estadístico de las columnas numéricas
display(usrs['age'].describe())
print()
display(usrs.describe())
# Out:
# count    4000.000000
# mean       48.136000
# std        17.689919
# min        18.000000
# 25%        33.000000
# 50%        48.000000
# 75%        63.000000
# max        79.000000
# Name: age, dtype: float64
#             user_id          age                       reg_date  \
# count   4000.000000  4000.000000                           3960
# mean   11999.500000    48.136000  2023-07-03 21:39:41.095273728
# min    10000.000000    18.000000            2022-01-01 00:00:00
# 25%    10999.750000    33.000000  2022-10-02 20:17:11.657914368
# 50%    11999.500000    48.000000  2023-07-04 10:00:05.401350400
# 75%    12999.250000    63.000000  2024-04-03 04:00:05.401350400
# max    13999.000000    79.000000            2024-12-31 00:00:00
# std     1154.844867    17.689919                            NaN
#
#                           churn_date   is_churned
# count                            466  4000.000000
# mean   2024-09-11 11:41:11.244635136     0.116500
# ...

# %%
# Distribución porcentual del tipo de plan
usrs['plan'].value_counts(normalize=True) * 100
# Out:
# plan
# Basico     64.875
# Premium    35.125
# Name: proportion, dtype: float64

# %% [markdown]
# ---
# **Comentarios:**
# - La base de usuarios tiene una distribución de edad equilibrada, con un promedio cercano a 48 años.
# - El servicio es utilizado por un amplio rango generacional (18–79 años).
# - La mayoría de clientes está registrada entre 2022 y 2024, lo que indica una base relativamente reciente.
# - El plan Básico domina el mercado: 64.87% de los usuarios, lo cual probablemente influirá en los patrones de consumo de llamadas y mensajes.
# ---

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Visualización de distribuciones (uso y clientes) y outliers
#
#
# ### 5.1 Visualización de Distribuciones
#
# 🎯 **Objetivo:**
# Entender visualmente cómo se comportan las variables clave tanto de **uso** como de **clientes**, observar si existen diferencias según el tipo de plan, y analizar la **forma de la distribución**.
#
# **Instrucciones:**
# Graficar **histogramas** para las siguientes columnas:
# - `age` (edad de los usuarios)
# - `cant_mensajes`
# - `cant_llamadas`
# - `total_minutos_llamada`
#
# Después de cada gráfico, escribe un **insight** respecto al plan y la variable, por ejemplo:
# - "Dentro del plan Premium, hay mayor proporción de..."
# - "Los usuarios Básico tienden a hacer ... llamadas y enviar ... mensajes."  o "No existe algún patrón."
# - ¿Qué tipo de distribución tiene ? (simétrica, sesgada a la derecha o a la izquierda)
#
# **Hint**
# Para cada histograma,
# - Usa `hue='plan'` para ver cómo varían las distribuciones según el plan (Básico o Premium).
# - Usa `palette=['skyblue','green']`
# - Agrega título y etiquetas

# %%
# Histograma para visualizar la edad (age)
plt.figure(figsize=(8,5))

sns.histplot(
    data=user_profile,
    x='age',
    hue='plan',
    bins=60,
    palette=['skyblue','green'],
    kde=True
)

plt.title('Distribución de edad de usuarios por tipo de plan')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')

plt.savefig('edad_por_plan.png',dpi=100)
plt.show()

# %% [markdown]
# Insights **Distribución de edad de usuarios por tipo de plan**:
# - La distribución de edades es aproximadamente simétrica.
# - La edad por sí sola no parece ser un factor determinante para elegir el tipo de plan.

# %%
# Histograma para visualizar la cant_mensajes
plt.figure(figsize=(8,5))

sns.histplot(
    data=user_profile,
    x='cant_mensajes',
    hue='plan',
    bins=60,
    palette=['skyblue','green'],
    kde=True
)

plt.title('Distribución de cantidad de mensajes por plan')
plt.xlabel('Cantidad de mensajes')
plt.ylabel('Frecuencia')

plt.savefig('mensajes_por_plan.png',dpi=100)
plt.show()

# %% [markdown]
# Insights **Distribución de cantidad de mensajes por plan**:
# - La distribución presenta sesgo a la derecha, indicando que la mayoría de los usuarios envían pocos mensajes, mientras que un grupo pequeño envía muchos.
# - El envío de mensajes es relativamente bajo y concentrado en un rango pequeño para ambos planes. Esto podría indicar que los SMS no son el principal canal de comunicación para la mayoría de los usuarios, posiblemente debido al uso de aplicaciones de mensajería.

# %%
# Histograma para visualizar la cant_llamadas
plt.figure(figsize=(8,5))

sns.histplot(
    data=user_profile,
    x='cant_llamadas',
    hue='plan',
    bins=60,
    palette=['skyblue','green'],
    kde=True
)

plt.title('Distribución de cantidad de llamadas por plan')
plt.xlabel('Cantidad de llamadas')
plt.ylabel('Frecuencia')

plt.savefig('llamadas_por_plan.png',dpi=100)
plt.show()

# %% [markdown]
# Insights **Distribución de cantidad de llamadas por plan**:
# - La distribución también presenta sesgo positivo.
# - La mayoría de usuarios realiza pocas llamadas, mientras que algunos usuarios muestran un uso intensivo.
# - Los usuarios del plan Premium tienden a realizar ligeramente más llamadas, lo que podría reflejar un mayor uso del servicio.

# %%
plt.figure(figsize=(8,5))

ax = sns.histplot(
    data=user_profile,
    x='cant_minutos_llamada',
    hue='plan',
    bins=60,
    palette=['skyblue','green'],
    kde=True
)

# línea vertical para media/promedio
linea_media = plt.axvline(
    user_profile['cant_minutos_llamada'].mean(),
    color='red', linestyle="--", label='Media'
)
# línea vertical para mediana
linea_mediana = plt.axvline(
    user_profile['cant_minutos_llamada'].median(),
    color='blue', linestyle="--", label='Mediana'
)

# obtener la leyenda existente creada por seaborn
legend = ax.get_legend()
handles = legend.legend_handles
labels = [text.get_text() for text in legend.get_texts()]

# agregar media y mediana
handles += [linea_media, linea_mediana]
labels += ['Media', 'Mediana']

# reconstruir leyenda
ax.legend(handles, labels, title='plan')

plt.title('Distribución de minutos totales de llamada por plan')
plt.xlabel('Minutos de llamada')
plt.ylabel('Frecuencia')

plt.savefig('minutos_llamada_por_plan.png',dpi=100)
plt.show()

# %% [markdown]
# Insights **Distribución de minutos totales de llamada por plan**:
# - La distribución muestra sesgo a la derecha, con muchos usuarios que consumen pocos minutos y algunos que consumen muchos.
# - La media se ubica a la derecha de la mediana, indicando que algunos usuarios concentran un volumen alto de minutos.
# - Esto sugiere la existencia de usuarios intensivos del servicio

# %% [markdown]
# ### 5.2 Identificación de Outliers
#
# 🎯 **Objetivo:**
# Detectar valores extremos en las variables clave de **uso** y **clientes** que podrían afectar el análisis, y decidir si requieren limpieza o revisión adicional.
#
# **Instrucciones:**
# - Usa **boxplots** para identificar visualmente outliers en las siguientes columnas:
#   - `age`
#   - `cant_mensajes`
#   - `cant_llamadas`
#   - `total_minutos_llamada`
# - Crea un **for** para generar los 4 boxplots automáticamente.
# <br>
#
# - Después de crear los gráfico, responde si **existen o no outliers** en las variables.
# - Si hay outliers, crea otro bucle para calcular los límites de esas columnas usando el **método IQR** y decide qué hacer con ellos.
#   - Si solamente hay outliers de un solo lado, no es necesario calcular ambos límites.
#
# **Hint:**
# - Dentro del bucle, usa `plt.title(f'Boxplot: {col}')` para que el título cambie acorde a la columna.

# %%
# Visualizando usando BoxPlot
columnas_numericas = ['age', 'cant_mensajes', 'cant_llamadas', 'cant_minutos_llamada']

for col in columnas_numericas:

    plt.figure(figsize=(6,2.5))

    sns.boxplot(data=user_profile, x=col, color='skyblue')

    plt.title(f'Boxplot: {col}')
    plt.xlabel(col)
    plt.savefig(f'boxplot_{col}.png',dpi=77)
    plt.show()

# %% [markdown]
# Insights **Boxplots**:
# - Age: sin outliers.
# - cant_mensajes: outliers en extremo superior, representando usuarios con alto uso de mensajes. Uso real.
# - cant_llamadas: outliers en extremo superior, representando usuarios intensivos. Uso real.
# - cant_minutos_llamada: Outliers superiores claros. Usuarios intensivos. Uso real.

# %%
# Calcular límites con el método IQR
columnas_limites = ['cant_mensajes', 'cant_llamadas', 'cant_minutos_llamada']

for col in columnas_limites:

    Q1 = user_profile[col].quantile(0.25)
    Q3 = user_profile[col].quantile(0.75)

    IQR = Q3 - Q1

    limite_superior = Q3 + 1.5 * IQR
    outliers_sup = user_profile[user_profile[col] > limite_superior]

    print(f"\nColumna: {col}")
    print(f"Límite superior: {limite_superior}")
    print(f"Outliers superiores: {len(outliers_sup)}")
# Out:
# Columna: cant_mensajes
# Límite superior: 11.5
# Outliers superiores: 45
#
# Columna: cant_llamadas
# Límite superior: 10.5
# Outliers superiores: 30
#
# Columna: cant_minutos_llamada
# Límite superior: 61.45
# Outliers superiores: 94

# %%
# Revisa los limites superiores y el max, para tomar la decisión de mantener los outliers o no
user_profile[columnas_limites].describe()
# Out:
#        cant_mensajes  cant_llamadas  cant_minutos_llamada
# count    3999.000000    3999.000000           3999.000000
# mean        5.518380       4.471618             22.808747
# std         2.358046       2.142878             16.582414
# min         0.000000       0.000000              0.000000
# 25%         4.000000       3.000000             11.000000
# 50%         5.000000       4.000000             19.730000
# 75%         7.000000       6.000000             31.180000
# max        17.000000      15.000000            155.690000

# %% [markdown]
# Insights **Límites IQR**:
# - cant_mensajes: Representan usuarios con alto uso de SMS. No se eliminan porque reflejan comportamiento real.
# - cant_llamadas: Probablemente corresponden a usuarios con uso intensivo del servicio. No se eliminan porque reflejan comportamiento real.
# - cant_minutos_llamada: Estos usuarios pueden representar heavy users o clientes con mayor necesidad del servicio. No se eliminan porque reflejan comportamiento real.

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Segmentación de Clientes
#
# ### 6.1 Segmentación de Clientes Por Uso
#
# 🎯 **Objetivo:** Clasificar a cada usuario en un grupo de uso (Bajo uso, Uso medio, Alto uso) basándose en la cantidad de llamadas y mensajes registrados.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_uso` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones de llamadas y mensajes y asigna:
#   - `'Bajo uso'` cuando llamadas < 5 y mensajes < 5
#   - `'Uso medio'` cuando llamadas < 10 y mensajes < 10
#   - `'Alto uso'` para el resto de casos

# %%
# Crear columna grupo_uso

# %%
# verificar cambios
user_profile.head()

# %% [markdown]
# ### 6.2 Segmentación de Clientes Por Edad
#
# 🎯 **Objetivo:**: Clasificar a cada usuario en un grupo por **edad**.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_edad` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones y asigna:
#   - `'Joven'` cuando age < 30
#   - `'Adulto'` cuando age < 60
#   - `'Adulto Mayor'` para el resto de casos

# %%
# Crear columna grupo_edad

# %%
# verificar cambios
user_profile.head()

# %% [markdown]
# ### 6.3 Visualización de la Segmentación de Clientes
#
# 🎯 **Objetivo:** Visualizar la distribución de los usuarios según los grupos creados: **grupo_uso** y **grupo_edad**.
#
# **Instrucciones:**
# - Crea dos gráficos para las variables categóricas `grupo_uso` y `grupo_edad`.
# - Agrega título y etiquetas a los ejes en cada gráfico.

# %%
# Visualización de los segmentos por uso
sns.countplot(...)

plt.show()

# %%
# Visualización de los segmentos por edad

# %% [markdown]
# ---
# ## 🧩Paso 7: Insight Ejecutivo para Stakeholders
#
# 🎯 **Objetivo:** Traducir los hallazgos del análisis en conclusiones accionables para el negocio, enfocadas en segmentación, patrones de uso y oportunidades comerciales.
#
# **Preguntas a responder:**
# - ¿Qué problemas tenían originalmemte los datos?¿Qué porcentaje, o cantidad de filas, de esa columna representaban?
#
#
# - ¿Qué segmentos de clientes identificaste y cómo se comportan según su edad y nivel de uso?
# - ¿Qué segmentos parecen más valiosos para ConnectaTel y por qué?
# - ¿Qué patrones de uso extremo (outliers) encontraste y qué implican para el negocio?
#
#
# - ¿Qué recomendaciones harías para mejorar la oferta actual de planes o crear nuevos planes basados en los segmentos y patrones detectados?
#
# ✍️ **Escribe aquí tu análisis ejecutivo:**

# %% [markdown]
# ### Análisis ejecutivo
#
# ⚠️ **Problemas detectados en los datos**
# - abc
# - abc
#
#
# 🔍 **Segmentos por Edad**
# - abc
# - abc
#
#
# 📊 **Segmentos por Nivel de Uso**
# - abc
# - abc
#
#
# ➡️ Esto sugiere que ...
#
#
# 💡 **Recomendaciones**
# - abc
# - abc

# %% [markdown]
# ---
#
# ## 🧩Paso 8 Cargar tu notebook y README a GitHub
#
# 🎯 **Objetivo:**
# Entregar tu análisis de forma **profesional**, **documentada** y **versionada**, asegurando que cualquier persona pueda revisar, ejecutar y entender tu trabajo.
#
#
#
# ### Opción A : Subir archivos desde la interfaz de GitHub (UI)
#
# 1. Descarga este notebook (`File → Download .ipynb`).
# 2. Entra a tu repositorio en GitHub (por ejemplo `telecom-analysis` o `sprint7-final-project`).
# 3. Sube tu notebook **Add file → Upload files**.
#
# ---
#
# ### Opción B : Guardar directo desde Google Colab
#
# 1. Abre tu notebook en Colab.
# 2. Ve a **File → Save a copy in GitHub**.
# 3. Selecciona el repositorio y la carpeta correcta (ej: `notebooks/`).
# 4. Escribe un mensaje de commit claro, por ejemplo:
#     - `feat: add final ConnectaTel analysis`
#     - `agregar version final: Análisis ConnectaTel`
# 5. Verifica en GitHub que el archivo quedó en el lugar correcto y que el historial de commits se mantenga limpio.
#
# ---
#
# Agrega un archivo `README.md` que describa de forma clara:
# - el objetivo del proyecto,
# - los datasets utilizados,
# - las etapas del análisis realizadas,
# - cómo ejecutar el notebook (por ejemplo, abrirlo en Google Colab),
# - una breve guía de reproducción.
# ---

# %% [markdown]
# Link a repositorio público del proyecto: `LINK a tu repo aquí`
